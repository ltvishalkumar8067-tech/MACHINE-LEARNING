# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\Ml project\WeatherTemperature.csv")
df
# Out:
#    City_code  temperature
# 0          1         94.0
# 1          2         97.2
# 2          3         58.8
# 3          4        -10.9
# 4          5        -15.5

# %%
# %matplotlib inline
plt.xlabel('City_code')
plt.ylabel('temperature')
plt.scatter(df.City_code, df.temperature,color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['City_code']],df.temperature)
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-163407.15])

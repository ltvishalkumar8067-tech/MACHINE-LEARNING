# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\Ml project\TemperaturevsIce_Cream_Sales_Dataset.csv")
df
# Out:
#    temperature  ice_cream_sales
# 0        35.87           685.93
# 1        52.54            24.75
# 2        61.40           290.39
# 3        56.12           210.05
# 4         3.31           204.42

# %%
# %matplotlib inline
plt.xlabel('temperature')
plt.ylabel('ice_cream_sales')
plt.scatter(df.temperature, df.ice_cream_sales,color='black',marker='*')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['temperature']],df.ice_cream_sales)
# Out:
# LinearRegression()

# %%
reg.predict([[56000]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-76258.95898241])

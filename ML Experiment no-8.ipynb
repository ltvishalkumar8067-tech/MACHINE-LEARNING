# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\Ml project\class average.csv")
df
# Out:
#    class_size  average_marks
# 0          20             78
# 1          25             76
# 2          30             74
# 3          35             72
# 4          40             70

# %%
# %matplotlib inline
plt.xlabel('class_size')
plt.ylabel('average_marks')
plt.scatter(df.class_size, df.average_marks,color='black',marker='*')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['class_size']],df.average_marks)
# Out:
# LinearRegression()

# %%
reg.predict([[5999000]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-2399514.])

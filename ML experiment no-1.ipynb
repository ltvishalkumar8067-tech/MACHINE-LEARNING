# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\vish.csv")
df
# Out:
#    x  y
# 0  1  3
# 1  2  4
# 2  3  2
# 3  4  4
# 4  5  5

# %%
# %matplotlib inline
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(df.x, df.y,color='red',marker='*')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['x']],df.y)
# Out:
# LinearRegression()

# %%
reg.predict([[5]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.4])

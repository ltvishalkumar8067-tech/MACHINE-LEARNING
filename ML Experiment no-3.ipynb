# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\experiment no-3 ml.csv")
df
# Out:
#    Hours_Study  Marks
# 0            1     50
# 1            2     60
# 2            3     70
# 3            4     40
# 4            5     80

# %%
# %matplotlib inline
plt.xlabel("Hours_Study")
plt.ylabel("Marks")
plt.scatter(df.Hours_Study, df.Marks,color='green',marker='*')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['Hours_Study']],df.Marks)
# Out:
# LinearRegression()

# %%
reg.predict([[500000]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2000048.])

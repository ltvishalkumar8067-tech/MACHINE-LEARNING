# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\Ml project\ml experiment no-10.csv")
df
# Out:
#     marks  result
# 0      34       0
# 1      70       1
# 2      12       0
# 3      61       1
# 4      84       1
# 5      21       0
# 6      14       0
# 7      31       0
# 8      29       0
# 9      98       1
# 10     74       1
# 11     88       1
# 12     26       0
# 13     20       1
# 14     50       0

# %%
# %matplotlib inline
plt.xlabel('marks')
plt.ylabel('result')
plt.scatter(df.marks, df.result,color='black',marker='+')

# %%
x_train,x_test,y_train,y_test = train_test_split(df[['marks']], df['result'], test_size=0.3,)
len(x_train)
# Out:
# 10

# %%
model= LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[20]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\experiment no-2 ml.csv")
df
# Out:
#       x   y
# 0   500  20
# 1   750  30
# 2  1000  40
# 3  1250  50
# 4  1500  60

# %%
# %matplotlib inline
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(df.x, df.y,color='black',marker='*')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['x']],df.y)
# Out:
# LinearRegression()

# %%
reg.predict([[500000]])3
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16537.85123967])

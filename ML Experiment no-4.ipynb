# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\Ml project\experiment no-4 ml.csv")
df
# Out:
#    Engine_Size  Fuel_Efficience
# 0          1.0               20
# 1          1.5               18
# 2          2.0               16
# 3          2.5               14
# 4          3.0               12

# %%
# %matplotlib inline
plt.xlabel('Engine_size')
plt.ylabel('Fuel_Efficience')
plt.scatter(df.Engine_Size, df.Fuel_Efficience,color='blue',marker='+')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['Engine_Size']],df.Fuel_Efficience)
# Out:
# LinearRegression()

# %%
reg.predict([[5000000000000000000000]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-2e+22], dtype=object)

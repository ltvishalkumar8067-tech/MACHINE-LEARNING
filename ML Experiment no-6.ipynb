# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\visha\OneDrive\Desktop\Ml project\SalaryvsExperienceDataset.csv")
df
# Out:
#       salary  experience
# 0   46846.34         6.8
# 1   90225.44        21.6
# 2  104199.61        20.2
# 3   92738.86        20.8
# 4   60691.43        15.0

# %%
# %matplotlib inline
plt.xlabel('salary')
plt.ylabel('experience')
plt.scatter(df.salary, df.experience,color='red',marker='*')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['salary']],df.experience)
# Out:
# LinearRegression()

# %%
reg.predict([[5]])
# Out:
# C:\Users\visha\.vscode\mypythonamity\my program\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-1.8096054])
